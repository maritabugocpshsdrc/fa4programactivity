# %% [markdown]
# <a href="https://colab.research.google.com/github/maritabugocpshsdrc/fa4programactivity/blob/main/fa4program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for num in range(1, 21):
    if num % 2 == 0:
        continue
    print(num)

# %%
password = "drcbatch31emerald"

while True:
  input_password = input("Enter password: ")

  if input_password == password:
    print("Access granted!")
    break
  else:
    print("Access denied. Try again.")
# Out:
# Enter password: drcbatch31eme
# Access denied. Try again.
# Enter password: drcbatch31emerald
# Access granted!

# %%
# Out:
# 6

# %%
for number in range(1, 11):
    if number == 4:
        continue
    elif number == 6:
        pass
    elif number == 8:
        break
    print(number)
